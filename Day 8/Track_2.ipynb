# %% [markdown]
# <a href="https://colab.research.google.com/github/Shalini-byte-stack/VEL-TECH-SUMMER-INTERNSHIP/blob/main/Track_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b93b01ba-8122-4218-959d-767a4d9e28dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b93b01ba-8122-4218-959d-767a4d9e28dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Description – Isolation Forest with Grid Search on HeartRate-Mat.csv
#
# This project uses the Isolation Forest machine learning algorithm to detect abnormal heart rate readings from the HeartRate-Mat.csv dataset. To improve model performance, Grid Search is used to test multiple combinations of hyperparameters such as the number of trees (n_estimators), contamination rate, and sample size. The best parameter combination is selected automatically based on the model's anomaly detection performance.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import ParameterGrid
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("HeartRate-Mat.csv")

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'contamination': [0.01, 0.05, 0.1],
    'max_samples': ['auto']
}

# %%
from sklearn.model_selection import ParameterGrid

# %%
print(df.head())
print(df.columns)
# Out:
#   patient_id  heart_rate  spo2_level  ecg_signal  respiration_rate  \
# 0       P075          62        98.4      -0.001                14
# 1       P019          75        98.7       0.123                14
# 2       P039          89        94.0      -0.580                18
# 3       P078          82        92.2       0.400                14
# 4       P005          87        97.8      -0.146                18
#
#    body_temperature  blood_pressure_sys  blood_pressure_dia  blood_glucose  \
# 0              36.2                 125                  86          117.5
# 1              36.3                 120                  85          142.7
# 2              37.2                 130                  84           94.6
# 3              37.0                 115                  82          162.3
# 4              36.6                 118                  84          103.5
#
#    eeg_alpha_power  eeg_beta_power  emg_signal_strength  fall_detected  \
# ...

# %% [markdown]
# Output Description
#
# The program successfully applies the Isolation Forest algorithm with Grid Search to the HeartRate-Mat.csv dataset. Grid Search evaluates different combinations of hyperparameters and selects the best-performing model for anomaly detection
